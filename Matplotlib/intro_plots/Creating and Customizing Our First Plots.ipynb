# %%
import numpy as np
from matplotlib import pyplot as plt

age_x = [21, 25, 26, 27, 28, 29, 30, 31, 32, 35]

x_indexes = np.arange(len(age_x))
width=0.25

#THE DEVS SALARIES
py_dev_y = [70000, 80000, 95000, 110000, 125000, 140000, 155000, 175000, 190000,  210000]

js_dev_y = [65000, 75000, 85000, 95000, 110000, 125000, 140000, 155000, 170000, 185000]

dev_y = [30000, 40000, 45000, 50000, 60000, 62000, 65000, 70000, 72000, 85000]

#PLOT THE BAR CHART
plt.bar(x_indexes + width, dev_y, width =width, color='b', label='All Devs')
plt.bar(x_indexes - width, py_dev_y, width = width, color='k', label='Ml eng')
plt.bar(x_indexes, js_dev_y, width = width, color='orange', label='js_dev')

#LABELS
plt.xticks(ticks=x_indexes, labels=age_x)
plt.xlabel('Ages')
plt.ylabel('Median Salary(USD)')
plt.title('Median Salary(USD) by Age')
plt.xkcd
plt.legend()
plt.grid(True)
plt.tight_layout() 
plt.savefig('barplot.png')
plt.show()
